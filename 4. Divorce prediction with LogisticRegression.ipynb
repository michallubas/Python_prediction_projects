# %% [markdown]
#     The main goal is to predict if couple will divorce or not , base on 170 entries and 55 attributes (questions to couples)

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('divorce.csv',sep=';')

# %%
df.head(5)
# Out:
#    Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  Atr7  Atr8  Atr9  Atr10  ...  Atr46  \
# 0     2     2     4     1     0     0     0     0     0      0  ...      2
# 1     4     4     4     4     4     0     0     4     4      4  ...      2
# 2     2     2     2     2     1     3     2     1     1      2  ...      3
# 3     3     2     3     2     3     3     3     3     3      3  ...      2
# 4     2     2     1     1     1     1     0     0     0      0  ...      2
#
#    Atr47  Atr48  Atr49  Atr50  Atr51  Atr52  Atr53  Atr54  Class
# 0      1      3      3      3      2      3      2      1      1
# 1      2      3      4      4      4      4      2      2      1
# 2      2      3      1      1      1      2      2      2      1
# 3      2      3      3      3      3      2      2      2      1
# 4      1      2      3      2      2      2      1      0      1
#
# [5 rows x 55 columns]

# %%
df_attributes=pd.read_excel('Attribute Information.xlsx',index_col=0)

# %%
df_attributes.head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: [2. I know we can ignore our differences, even if things get hard sometimes., 3. When we need it, we can take our discussions with my spouse from the beginning and correct it., 4. When I discuss with my spouse, to contact him will eventually work., 5. The time I spent with my wife is special for us., 6. We don't have time at home as partners.]

# %%
df.describe()
# Out:
#              Atr1        Atr2        Atr3        Atr4        Atr5        Atr6  \
# count  170.000000  170.000000  170.000000  170.000000  170.000000  170.000000
# mean     1.776471    1.652941    1.764706    1.482353    1.541176    0.747059
# std      1.627257    1.468654    1.415444    1.504327    1.632169    0.904046
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      2.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 75%      3.000000    3.000000    3.000000    3.000000    3.000000    1.000000
# max      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
#
#              Atr7        Atr8        Atr9       Atr10  ...       Atr46  \
# count  170.000000  170.000000  170.000000  170.000000  ...  170.000000
# mean     0.494118    1.452941    1.458824    1.576471  ...    2.552941
# ...

# %%
sns.countplot(x='Class', data=df)

# %% [markdown]
# Test data with  Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\michal.lubas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %% [markdown]
# Check model

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print( classification_report(y_test,predictions))
print( confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        28
#            1       1.00      0.96      0.98        23
#
#     accuracy                           0.98        51
#    macro avg       0.98      0.98      0.98        51
# weighted avg       0.98      0.98      0.98        51
#
# [[28  0]
#  [ 1 22]]

# %% [markdown]
# Very high precision with using the LogisticRegression
